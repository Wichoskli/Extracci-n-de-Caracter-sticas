# %% [markdown]
# <a href="https://colab.research.google.com/github/Wichoskli/Extracci-n-de-Caracter-sticas/blob/main/Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv
from google.colab import files
files.upload()

# %%
#Importar archivo
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Realizamos una copia del dataframe
data=Micro_Retailer.copy()

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop     73
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Quinto Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante "forward fill" "forawrd fill" ("ffill")
#Filtro por columnas
data["234_willingness_participate_workshop"]=data["234_willingness_participate_workshop"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop      0
# 318_shopkeeper_name                     123
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
data["318_shopkeeper_name"] = data["318_shopkeeper_name"].fillna("Anónimo")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop      0
# 318_shopkeeper_name                       0
# 319_shopkeepers_last_name               125
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
data["319_shopkeepers_last_name"] = data["319_shopkeepers_last_name"].fillna("Anónimo")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop      0
# 318_shopkeeper_name                       0
# 319_shopkeepers_last_name                 0
# 236_whatsapp                            129
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
data["236_whatsapp"] = data["236_whatsapp"].fillna("Anónimo")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop      0
# 318_shopkeeper_name                       0
# 319_shopkeepers_last_name                 0
# 236_whatsapp                              0
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
data["236_whatsapp"] = data["236_whatsapp"].fillna("Anónimo")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                0
# _title                                    0
# _server_updated_at                        0
# _updated_by                               0
# _geometry                                 0
#                                        ...
# 234_willingness_participate_workshop      0
# 318_shopkeeper_name                       0
# 319_shopkeepers_last_name                 0
# 236_whatsapp                              0
# 235_email                               142
# Length: 106, dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
data["235_email"] = data["235_email"].fillna("Anónimo")

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    0
# 318_shopkeeper_name                     0
# 319_shopkeepers_last_name               0
# 236_whatsapp                            0
# 235_email                               0
# Length: 106, dtype: int64

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(22), int64(2), object(82)
# memory usage: 141.7+ KB

# %%
#Obtener variables cuantitativas
Cuantitativas = data.select_dtypes(include=['int', 'float'])
Cuantitativas

# %%
#Obtener variables cualitativas
Cualitativas = data.select_dtypes(include=['object'])
Cualitativas

# %%
#Verificar información de variables cuantitativas
Cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   _latitude                                          171 non-null    float64
#  1   _longitude                                         171 non-null    float64
#  2   97_number_of_customers_in_store                    171 non-null    int64
#  3   268_number_fridges                                 168 non-null    float64
#  4   104_how_many_shelves_does_the_micro_retailer_have  171 non-null    int64
#  5   2_current_permanent_employees                      111 non-null    float64
#  6   4_number_permanent_employees_last_year             95 non-null     float64
#  7   103_number_own_fridges                             27 non-null     float64
# ...

# %%
#Verificar información de variables cualitativas
Cualitativas.info()

# %%
#Identificar valores nulos por columnas en tabla de variables cuantitativas

valores_nulos = Cuantitativas.isnull().sum()
valores_nulos
# Out:
# _latitude                                              0
# _longitude                                             0
# 97_number_of_customers_in_store                        0
# 268_number_fridges                                     0
# 104_how_many_shelves_does_the_micro_retailer_have      0
# 2_current_permanent_employees                          0
# 4_number_permanent_employees_last_year                 0
# 103_number_own_fridges                                 0
# 145_number_direct_competitors                          0
# 24_burnout                                             0
# 271_card_fee                                         171
# 272_card_days_receive_money                            0
# 273_platform_extra_charge                            171
# 274_platform_fee                                     171
# 275_platform_days_receive_money                      171
# 276_expected_days_informal_credit                      0
# ...

# %%
#Sustituir valores nulos numericos con promedio o media
Nulos = [3] + list(range(5,24)) #Se seleccionan la columna 3 y de la 5 a la 24 que involucran todos los valores nulos
Cuantitativas.iloc[:, Nulos] = Cuantitativas.iloc[:, Nulos].fillna(round(Cuantitativas.iloc[:, Nulos].mean(),1))
valores_nulos = Cuantitativas.isnull().sum()
valores_nulos
# Out:
# _latitude                                              0
# _longitude                                             0
# 97_number_of_customers_in_store                        0
# 268_number_fridges                                     0
# 104_how_many_shelves_does_the_micro_retailer_have      0
# 2_current_permanent_employees                          0
# 4_number_permanent_employees_last_year                 0
# 103_number_own_fridges                                 0
# 145_number_direct_competitors                          0
# 24_burnout                                             0
# 271_card_fee                                         171
# 272_card_days_receive_money                            0
# 273_platform_extra_charge                            171
# 274_platform_fee                                     171
# 275_platform_days_receive_money                      171
# 276_expected_days_informal_credit                      0
# ...

# %%
#Para aquellas variables que no desapareciaron significa que sus 171 registros todos son nulos por lo que no se puede promediar nada
#Para evitar perder información, se aplica la sustitución a "NaN" para indicar que esos valores no fueron respondidos

Cuantitativas[["271_card_fee", "273_platform_extra_charge", "275_platform_days_receive_money", "274_platform_fee"]] = Cuantitativas[["271_card_fee", "273_platform_extra_charge", "275_platform_days_receive_money", "274_platform_fee"]].fillna("NaN")
valores_nulos = Cuantitativas.isnull().sum()
valores_nulos

# %%
#Se observa otra vez la información de las variables cuantitativas
#Todo aquello clasificado como "NaN" se vuelven objeto

Cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   _latitude                                          171 non-null    float64
#  1   _longitude                                         171 non-null    float64
#  2   97_number_of_customers_in_store                    171 non-null    int64
#  3   268_number_fridges                                 171 non-null    float64
#  4   104_how_many_shelves_does_the_micro_retailer_have  171 non-null    int64
#  5   2_current_permanent_employees                      171 non-null    float64
#  6   4_number_permanent_employees_last_year             171 non-null    float64
#  7   103_number_own_fridges                             171 non-null    float64
# ...

# %%
#Se extraen las variables que se mantuvieron como cuantitativas de la tabla de variables cuantitativas

Cuantitativas2 = Cuantitativas.select_dtypes(include=['int', 'float'])
Cuantitativas2
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                                2
# 1    19.053561  -98.234142                                0
# 2    19.058655  -98.232300                                0
# 3    19.059293  -98.233158                                0
# 4    19.059585  -98.233864                                0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                                1
# 167  19.042794  -98.193802                                1
# 168  19.042809  -98.193439                                3
# 169  19.042558  -98.193818                                0
# 170  19.042823  -98.193735                                1
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                  4
# 1                   4.0                                                  8
# ...

# %%
#Corroboramos información de cuantitativas
Cuantitativas2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   _latitude                                          171 non-null    float64
#  1   _longitude                                         171 non-null    float64
#  2   97_number_of_customers_in_store                    171 non-null    int64
#  3   268_number_fridges                                 171 non-null    float64
#  4   104_how_many_shelves_does_the_micro_retailer_have  171 non-null    int64
#  5   2_current_permanent_employees                      171 non-null    float64
#  6   4_number_permanent_employees_last_year             171 non-null    float64
#  7   103_number_own_fridges                             171 non-null    float64
# ...

# %%
#Bigote de cada columna del dataframe para revisión de valores Atipicos
fig = plt.figure(figsize =(15, 8))
Cuantitativas2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=Cuantitativas2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Se depuran valores atipicos
Cuantitativas2 = Cuantitativas2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
Cuantitativas2
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
#Corroboramos valores nulos
valores_nulos=Cuantitativas2.isnull().sum()
valores_nulos
# Out:
# _latitude                                             0
# _longitude                                            0
# 97_number_of_customers_in_store                       5
# 268_number_fridges                                   10
# 104_how_many_shelves_does_the_micro_retailer_have     9
# 2_current_permanent_employees                        15
# 4_number_permanent_employees_last_year               12
# 103_number_own_fridges                               27
# 145_number_direct_competitors                        15
# 24_burnout                                           38
# 272_card_days_receive_money                          14
# 276_expected_days_informal_credit                    24
# 36_credit_default_rate                               14
# 315_frequency_topups                                 10
# 316_frequency_utility_bills                           2
# 317_home_deliveries                                  17
# 62_frequency_only_services                           24
# ...

# %%
#Se rellenan los valores nulos que se generarón con la depuración de valores atipicos con el metodo de media

Cuantitativas2=Cuantitativas2.fillna(round(Cuantitativas2.mean(),1))
Cuantitativas2
# Out:
#      _latitude  _longitude  97_number_of_customers_in_store  \
# 0    19.053536  -98.233822                              2.0
# 1    19.053561  -98.234142                              0.0
# 2    19.058655  -98.232300                              0.0
# 3    19.059293  -98.233158                              0.0
# 4    19.059585  -98.233864                              0.0
# ..         ...         ...                              ...
# 166  19.043115  -98.194066                              1.0
# 167  19.042794  -98.193802                              1.0
# 168  19.042809  -98.193439                              3.0
# 169  19.042558  -98.193818                              0.0
# 170  19.042823  -98.193735                              1.0
#
#      268_number_fridges  104_how_many_shelves_does_the_micro_retailer_have  \
# 0                   0.0                                                4.0
# 1                   4.0                                                8.0
# ...

# %%
#Corroboramos valores nulos
valores_nulos=Cuantitativas2.isnull().sum()
valores_nulos
# Out:
# _latitude                                            0
# _longitude                                           0
# 97_number_of_customers_in_store                      0
# 268_number_fridges                                   0
# 104_how_many_shelves_does_the_micro_retailer_have    0
# 2_current_permanent_employees                        0
# 4_number_permanent_employees_last_year               0
# 103_number_own_fridges                               0
# 145_number_direct_competitors                        0
# 24_burnout                                           0
# 272_card_days_receive_money                          0
# 276_expected_days_informal_credit                    0
# 36_credit_default_rate                               0
# 315_frequency_topups                                 0
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  0
# 62_frequency_only_services                           0
# ...

# %%
#Bigote
fig = plt.figure(figsize =(15, 8))
Cuantitativas2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
#Se extraen las variables que se convirtieron en cualitativas de las variables cuantitativas

Cuantitativas3 = Cuantitativas.select_dtypes(include=['object'])
Cuantitativas3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   271_card_fee                     171 non-null    object
#  1   273_platform_extra_charge        171 non-null    object
#  2   274_platform_fee                 171 non-null    object
#  3   275_platform_days_receive_money  171 non-null    object
# dtypes: object(4)
# memory usage: 5.5+ KB

# %%
#Se unen las variables que originalmente eran cuantitativas

Cuantitativas = pd.concat([Cuantitativas3,Cuantitativas2], axis=1)
Cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   271_card_fee                                       171 non-null    object
#  1   273_platform_extra_charge                          171 non-null    object
#  2   274_platform_fee                                   171 non-null    object
#  3   275_platform_days_receive_money                    171 non-null    object
#  4   _latitude                                          171 non-null    float64
#  5   _longitude                                         171 non-null    float64
#  6   97_number_of_customers_in_store                    171 non-null    float64
#  7   268_number_fridges                                 171 non-null    float64
# ...

# %%
#Se revisa la información de las variables cualitativas

Cualitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 82 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   _record_id                                                  171 non-null    object
#  1   _title                                                      171 non-null    object
#  2   _server_updated_at                                          171 non-null    object
#  3   _updated_by                                                 171 non-null    object
#  4   _geometry                                                   171 non-null    object
#  5   228_store_name                                              171 non-null    object
#  6   229_store_picture                                           171 non-null    object
# ...

# %%
#Reemplazamos a NaN a variables cualitativas para eliminar nulos

Cualitativas = Cualitativas.fillna("NaN")
valores_nulos = Cualitativas.isnull().sum()
valores_nulos
# Out:
# _record_id                              0
# _title                                  0
# _server_updated_at                      0
# _updated_by                             0
# _geometry                               0
#                                        ..
# 234_willingness_participate_workshop    0
# 318_shopkeeper_name                     0
# 319_shopkeepers_last_name               0
# 236_whatsapp                            0
# 235_email                               0
# Length: 82, dtype: int64

# %%
#Se juntan las variables cuantitativas y las cualitativas

DATA = pd.concat([Cuantitativas,Cualitativas], axis=1)
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, 271_card_fee to 235_email
# dtypes: float64(20), object(86)
# memory usage: 141.7+ KB

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(DATA)
# Out:
#   271_card_fee  frequency  percentage  cumulative_perc
# 0          NaN        171         1.0              1.0
#
# ----------------------------------------------------------------
#
#   273_platform_extra_charge  frequency  percentage  cumulative_perc
# 0                       NaN        171         1.0              1.0
#
# ----------------------------------------------------------------
#
#   274_platform_fee  frequency  percentage  cumulative_perc
# 0              NaN        171         1.0              1.0
#
# ----------------------------------------------------------------
#
#   275_platform_days_receive_money  frequency  percentage  cumulative_perc
# 0                             NaN        171         1.0              1.0
#
# ----------------------------------------------------------------
#
#                                _record_id  frequency  percentage  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b          1    0.005848
# ...

# %% [markdown]
# **ANÁLISIS 1**

# %%
#Análisis univariado de una variable categórica en específico
table1 = freq_tbl(DATA['_title'])
table1
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304
# 7  November 11, 2022          1    0.005848         0.994152
# 8   November 2, 2022          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('_title')
Filtro_index
# Out:
#                    frequency  percentage  cumulative_perc
# _title
# November 9, 2022          73    0.426901         0.426901
# November 10, 2022         26    0.152047         0.578947
# November 7, 2022          20    0.116959         0.695906
# November 3, 2022          16    0.093567         0.789474
# November 12, 2022         15    0.087719         0.877193
# November 8, 2022          10    0.058480         0.935673
# November 4, 2022           9    0.052632         0.988304

# %%
#Gráfico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Días con mayores registros')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='_title'>

# %%
#Gráfico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 2**

# %%
#Análisis univariado de una variable categórica en específico
table2 = freq_tbl(DATA['_server_updated_at'])
table2
# Out:
#           _server_updated_at  frequency  percentage  cumulative_perc
# 0    2022-11-09 23:13:46 UTC          3    0.017544         0.017544
# 1    2022-11-11 22:11:34 UTC          3    0.017544         0.035088
# 2    2022-11-09 23:13:47 UTC          3    0.017544         0.052632
# 3    2022-11-12 22:15:09 UTC          3    0.017544         0.070175
# 4    2022-11-09 23:20:41 UTC          2    0.011696         0.081871
# ..                       ...        ...         ...              ...
# 127  2022-11-10 17:34:43 UTC          1    0.005848         0.976608
# 128  2022-11-10 17:34:47 UTC          1    0.005848         0.982456
# 129  2022-11-10 17:39:04 UTC          1    0.005848         0.988304
# 130  2022-11-10 17:46:56 UTC          1    0.005848         0.994152
# 131  2022-11-03 16:15:13 UTC          1    0.005848         1.000000
#
# [132 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table2[table2['frequency']>1]
Filtro1
# Out:
#          _server_updated_at  frequency  percentage  cumulative_perc
# 0   2022-11-09 23:13:46 UTC          3    0.017544         0.017544
# 1   2022-11-11 22:11:34 UTC          3    0.017544         0.035088
# 2   2022-11-09 23:13:47 UTC          3    0.017544         0.052632
# 3   2022-11-12 22:15:09 UTC          3    0.017544         0.070175
# 4   2022-11-09 23:20:41 UTC          2    0.011696         0.081871
# 5   2022-11-09 23:13:48 UTC          2    0.011696         0.093567
# 6   2022-11-07 20:47:54 UTC          2    0.011696         0.105263
# 7   2022-11-09 23:13:52 UTC          2    0.011696         0.116959
# 8   2022-11-09 18:32:01 UTC          2    0.011696         0.128655
# 9   2022-11-09 23:13:51 UTC          2    0.011696         0.140351
# 10  2022-11-11 22:11:32 UTC          2    0.011696         0.152047
# 11  2022-11-08 14:55:44 UTC          2    0.011696         0.163743
# 12  2022-11-10 18:59:55 UTC          2    0.011696         0.175439
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('_server_updated_at')
Filtro1_index
# Out:
#                          frequency  percentage  cumulative_perc
# _server_updated_at
# 2022-11-09 23:13:46 UTC          3    0.017544         0.017544
# 2022-11-11 22:11:34 UTC          3    0.017544         0.035088
# 2022-11-09 23:13:47 UTC          3    0.017544         0.052632
# 2022-11-12 22:15:09 UTC          3    0.017544         0.070175
# 2022-11-09 23:20:41 UTC          2    0.011696         0.081871
# 2022-11-09 23:13:48 UTC          2    0.011696         0.093567
# 2022-11-07 20:47:54 UTC          2    0.011696         0.105263
# 2022-11-09 23:13:52 UTC          2    0.011696         0.116959
# 2022-11-09 18:32:01 UTC          2    0.011696         0.128655
# 2022-11-09 23:13:51 UTC          2    0.011696         0.140351
# 2022-11-11 22:11:32 UTC          2    0.011696         0.152047
# 2022-11-08 14:55:44 UTC          2    0.011696         0.163743
# 2022-11-10 18:59:55 UTC          2    0.011696         0.175439
# ...

# %%
#Gráfico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Horario de actualización del servidor')
plt.xlabel('Fecha y hora')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro1_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro1_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro1_index["frequency"].plot(kind='pie', figsize=(20,10), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro1_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 3**

# %%
#Análisis univariado de una variable categórica en específico
table3 = freq_tbl(DATA['314_reception_delivery_packages'])
table3
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0                             NaN        103    0.602339         0.602339
# 1        Totalmente en desacuerdo         46    0.269006         0.871345
# 2                 Algo de acuerdo          9    0.052632         0.923977
# 3           Totalmente de acuerdo          8    0.046784         0.970760
# 4  Ni de acuerdo ni en desacuerdo          3    0.017544         0.988304
# 5              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table3[table3['frequency']>1]
Filtro2
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0                             NaN        103    0.602339         0.602339
# 1        Totalmente en desacuerdo         46    0.269006         0.871345
# 2                 Algo de acuerdo          9    0.052632         0.923977
# 3           Totalmente de acuerdo          8    0.046784         0.970760
# 4  Ni de acuerdo ni en desacuerdo          3    0.017544         0.988304
# 5              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro2_index= Filtro2.set_index('314_reception_delivery_packages')
Filtro2_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 314_reception_delivery_packages
# NaN                                    103    0.602339         0.602339
# Totalmente en desacuerdo                46    0.269006         0.871345
# Algo de acuerdo                          9    0.052632         0.923977
# Totalmente de acuerdo                    8    0.046784         0.970760
# Ni de acuerdo ni en desacuerdo           3    0.017544         0.988304
# Algo en desacuerdo                       2    0.011696         1.000000

# %%
#Gráfico de barras del dataframe filtrado
Filtro2_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Recepción y entrega de paquetes')
plt.xlabel('Opinión')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro2_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro2_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro2_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro2_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 4**

# %%
#OAnálisis univariado de una variable categórica en específico
table4 = freq_tbl(DATA['157_frequency_organize_shelves'])
table4
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                            NaN         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304
# 7                 Semestralmente          1    0.005848         0.994152
# 8                    No se tiene          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro3= table4[table4['frequency']>1]
Filtro3
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                            NaN         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro3_index= Filtro3.set_index('157_frequency_organize_shelves')
Filtro3_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro3_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Frecuencia de organización de estantería')
plt.xlabel('Continuidad')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro3_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro3_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro3_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro3_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 5**

# %%
#OAnálisis univariado de una variable categórica en específico
table5 = freq_tbl(DATA['_updated_by'])
table5

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro4= table5[table5['frequency']>1]
Filtro4

# %%
#Ajusto el indice de mi dataframe
Filtro4_index= Filtro4.set_index('_updated_by')
Filtro4_index

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro4_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Persona encargada del registro')
plt.xlabel('Nombres')
plt.ylabel('Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro4_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro4_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro4_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro4_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 6**

# %%
#OAnálisis univariado de una variable categórica en específico
table6 = freq_tbl(DATA['232_type_of_store'])
table6

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro5= table6[table6['frequency']>1]
Filtro5

# %%
#Ajusto el indice de mi dataframe
Filtro5_index= Filtro5.set_index('232_type_of_store')
Filtro5_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro5_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de tiendas')
plt.xlabel('Tiendas')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro5_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro5_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro5_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro5_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 7**

# %%
#OAnálisis univariado de una variable categórica en específico
table7 = freq_tbl(DATA['184_store_devices'])
table7

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro6= table7[table7['frequency']>1]
Filtro6

# %%
#Ajusto el indice de mi dataframe
Filtro6_index= Filtro6.set_index('184_store_devices')
Filtro6_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro6_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Dispositivos usados en la tienda')
plt.xlabel('Tipo de dispositivo')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro6_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro6_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro6_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro6_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 8**

# %%
#OAnálisis univariado de una variable categórica en específico
table8 = freq_tbl(DATA['5_change_store_space_last_year'])
table8

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table8[table8['frequency']>1]
Filtro7

# %%
#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('5_change_store_space_last_year')
Filtro7_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro7_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Cambio en el espacio de la tienda el ultimmo año')
plt.xlabel('Porcentaje')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro7_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro7_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro7_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 9**

# %%
#OAnálisis univariado de una variable categórica en específico
table9 = freq_tbl(DATA['6_change_employees_average_salary_last_year'])
table9

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro8= table9[table9['frequency']>1]
Filtro8

# %%
#Ajusto el indice de mi dataframe
Filtro8_index= Filtro8.set_index('6_change_employees_average_salary_last_year')
Filtro8_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro8_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Cambio en el salario promedio')
plt.xlabel('Porcentaje')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro8_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro8_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro8_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro8_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 10**

# %%
#OAnálisis univariado de una variable categórica en específico
table10 = freq_tbl(DATA['49_inventory_records'])
table10

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro9= table10[table10['frequency']>1]
Filtro9

# %%
#Ajusto el indice de mi dataframe
Filtro9_index= Filtro9.set_index('49_inventory_records')
Filtro9_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro9_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas con las cuales se realiza el registro de inventario')
plt.xlabel('Tipo de herramienta')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro9_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro9_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro9_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro9_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 11**

# %%
#OAnálisis univariado de una variable categórica en específico
table11 = freq_tbl(DATA['210_sales_channels'])
table11

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro10= table11[table11['frequency']>1]
Filtro10

# %%
#Ajusto el indice de mi dataframe
Filtro10_index= Filtro10.set_index('210_sales_channels')
Filtro10_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro10_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Canales de venta')
plt.xlabel('Tipos de canales')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro10_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro10_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro10_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro10_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 12**

# %%
#OAnálisis univariado de una variable categórica en específico
table12 = freq_tbl(DATA['189_payment_methods'])
table12

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro11= table12[table12['frequency']>1]
Filtro11

# %%
#Ajusto el indice de mi dataframe
Filtro11_index= Filtro11.set_index('189_payment_methods')
Filtro11_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro11_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Métodos de pago')
plt.xlabel('Tipo de método')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro11_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro11_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro11_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro11_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 13**

# %%
#OAnálisis univariado de una variable categórica en específico
table13 = freq_tbl(DATA['214_customer_relationship_tools'])
table13

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro12= table13[table13['frequency']>1]
Filtro12

# %%
#Ajusto el indice de mi dataframe
Filtro12_index= Filtro12.set_index('214_customer_relationship_tools')
Filtro12_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro12_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro12_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro12_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro12_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro12_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 14**

# %%
#OAnálisis univariado de una variable categórica en específico
table14 = freq_tbl(DATA['193_sales_planning_tools'])
table14

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro13= table14[table14['frequency']>1]
Filtro13

# %%
#Ajusto el indice de mi dataframe
Filtro13_index= Filtro13.set_index('193_sales_planning_tools')
Filtro13_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro13_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de planificación de ventas')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro13_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro13_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro13_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro13_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 15**

# %%
#OAnálisis univariado de una variable categórica en específico
table15 = freq_tbl(DATA['60_services'])
table15

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro14= table15[table15['frequency']>1]
Filtro14

# %%
#Ajusto el indice de mi dataframe
Filtro14_index= Filtro14.set_index('60_services')
Filtro14_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro14_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Servicios ofrecidos')
plt.xlabel('Tipo de servicio')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro14_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro14_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro14_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro14_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 16**

# %%
#OAnálisis univariado de una variable categórica en específico
table16 = freq_tbl(DATA['311_topups'])
table16

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro15= table16[table16['frequency']>1]
Filtro15

# %%
#Ajusto el indice de mi dataframe
Filtro15_index= Filtro15.set_index('311_topups')
Filtro15_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro15_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Topups')
plt.xlabel('Opinión')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro15_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro15_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro15_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro15_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 17**

# %%
#OAnálisis univariado de una variable categórica en específico
table17 = freq_tbl(DATA['312_payment_of_utilities'])
table17

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro16= table17[table17['frequency']>1]
Filtro16

# %%
#Ajusto el indice de mi dataframe
Filtro16_index= Filtro16.set_index('312_payment_of_utilities')
Filtro16_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro16_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Pago de utilidades')
plt.xlabel('Opinión')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro16_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro16_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro16_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro16_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 18**

# %%
#OAnálisis univariado de una variable categórica en específico
table18 = freq_tbl(DATA['313_home_deliveries'])
table18

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro17= table18[table18['frequency']>1]
Filtro17

# %%
#Ajusto el indice de mi dataframe
Filtro17_index= Filtro17.set_index('313_home_deliveries')
Filtro17_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro17_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Entrega a domicilio')
plt.xlabel('Opinión')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro17_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro17_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro17_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro17_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 19**

# %%
#OAnálisis univariado de una variable categórica en específico
table19 = freq_tbl(DATA['158_charact_organize_products_on_shelves'])
table19

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro18= table19[table19['frequency']>1]
Filtro18

# %%
#Ajusto el indice de mi dataframe
Filtro18_index= Filtro18.set_index('158_charact_organize_products_on_shelves')
Filtro18_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro18_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Organización de productos en estantes')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro18_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro18_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro18_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro18_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %% [markdown]
# **ANÁLISIS 20**

# %%
#OAnálisis univariado de una variable categórica en específico
table20 = freq_tbl(DATA['161_actions_stockouts'])
table20

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro19= table20[table20['frequency']>1]
Filtro19

# %%
#Ajusto el indice de mi dataframe
Filtro19_index= Filtro19.set_index('161_actions_stockouts')
Filtro19_index

# %%
#Gráfico de barras del dataframe filtrado
Filtro19_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('¿Que sucede cuando se agota el producto?')
plt.xlabel('Acciones')
plt.ylabel('Frecuencia')

# %%
#Gráfico de dispersión del dataframe filtrado
Filtro19_index.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Gráfico de área del dataframe filtrado
Filtro19_index.plot(kind='area', figsize=(10,4),alpha = 0.5)

# %%
#Gráfico de pastel del dataframe filtrado
Filtro19_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Gráfico hexagonal del dataframe filtrado
Filtro19_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))

# %%
#Convertir DataFrame a CSV
DATA.to_csv("Resultados.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files


files.download("Resultados.csv")
